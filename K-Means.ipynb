# %% [markdown]
#  #  <p style="text-align: center;">Technical Support Data Analysis

# %% [markdown]
# Technical support data can often be a rich source of information on opportunities for improving customer experience. The lesser the trouble customers have with the product the better. Even better when the customers are able to overcome
# technical challenge quickly with minimal effort. Let us analyze the tech support data and do some basic analysis on problem types, time to resolve the problem and channel of support that is most suitable

# %% [markdown]
# ## Loading the Dataset

# %%
import pandas as pd
import numpy as np

import matplotlib.pylab as plt
# %matplotlib inline

import seaborn as sns
from sklearn.model_selection  import train_test_split
from sklearn.cluster import KMeans

from scipy.stats import zscore

#import sklearn.metrics

tech_supp_df = pd.read_csv("technical_support_data-2.csv")
tech_supp_df.dtypes
# Out:
# PROBLEM_TYPE              object
# no_of_cases                int64
# Avg_pending_calls        float64
# Avg_resol_time             int64
# recurrence_freq          float64
# Replace_percent          float64
# In_warranty_percent        int64
# Post_warranty_percent      int64
# dtype: object

# %% [markdown]
# The dataset contains one record for each unique problem type. It has metrics for each type like count, average calls to resolve, average resolution time etc.

# %%
tech_supp_df.shape
# Out:
# (23, 8)

# %%
tech_supp_df.head()
# Out:
#                        PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 0   Temperature control not working          170                1.3
# 1  power chord does not tightly fit           12                2.0
# 2             Fan swing not working            5                1.0
# 3           Main switch does not on            3                2.0
# 4        Forgot mobile app password           45                2.3
#
#    Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 0              32             0.04              0.0                   75
# 1             150             0.01              0.5                    5
# 2              35             0.02              0.2                   90
# 3               8             0.01              0.7                    5
# 4              54             0.15              0.0                   99
#
#    Post_warranty_percent
# 0                     25
# 1                     95
# 2                     10
# 3                     95
# 4                      1

# %%
techSuppAttr=tech_supp_df.iloc[:,1:]
techSuppScaled=techSuppAttr.apply(zscore)
sns.pairplot(techSuppScaled,diag_kind='kde')

# %% [markdown]
# ## Group Data into similar clusters
#
# Now, we will use K-Means clustering to group data based on their attribute. First, we need to determine the optimal number of groups. For that we conduct the knee test to see where the knee happens.

# %%
#Finding optimal no. of clusters
from scipy.spatial.distance import cdist
clusters=range(1,10)
meanDistortions=[]

for k in clusters:
    model=KMeans(n_clusters=k)
    model.fit(techSuppScaled)
    prediction=model.predict(techSuppScaled)
    meanDistortions.append(sum(np.min(cdist(techSuppScaled, model.cluster_centers_, 'euclidean'), axis=1)) / techSuppScaled.shape[0])


#plt.plot(clusters, meanDistortions, 'bx-')
plt.plot(clusters, meanDistortions, 'r-o')
plt.xlabel('k')
plt.ylabel('Average distortion')
plt.title('Selecting k with the Elbow Method')
# Out:
# C:\Users\hho1\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Text(0.5, 1.0, 'Selecting k with the Elbow Method')

# %% [markdown]
# Though the bend is not coming out clearly as there are many bends, let us look at 3 clusters and 5 clusters

# %%
# Let us first start with K = 3
final_model=KMeans(3)
final_model.fit(techSuppScaled)
prediction=final_model.predict(techSuppScaled)

#Append the prediction 
tech_supp_df["GROUP"] = prediction
techSuppScaled["GROUP"] = prediction
print("Groups Assigned : \n")
tech_supp_df.head()
# Out:
# Groups Assigned :
#                        PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 0   Temperature control not working          170                1.3
# 1  power chord does not tightly fit           12                2.0
# 2             Fan swing not working            5                1.0
# 3           Main switch does not on            3                2.0
# 4        Forgot mobile app password           45                2.3
#
#    Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 0              32             0.04              0.0                   75
# 1             150             0.01              0.5                    5
# 2              35             0.02              0.2                   90
# 3               8             0.01              0.7                    5
# 4              54             0.15              0.0                   99
#
#    Post_warranty_percent  GROUP
# 0                     25      1
# 1                     95      0
# 2                     10      1
# 3                     95      0
# 4                      1      2

# %%
tech_supp_df[tech_supp_df["GROUP"]==0]
# Out:
#                                  PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 1            power chord does not tightly fit           12                2.0
# 3                     Main switch does not on            3                2.0
# 11              Cluttered with popup messages          230                1.3
# 16               Motor noise from the system           390                1.0
# 20  Battery backup does not get fully charged           29                2.2
# 21           Battery does not last full 8 hrs           43                2.1
# 22             Fan speed varies at on its own           78                2.2
#
#     Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 1              150             0.01             0.50                    5
# 3                8             0.01             0.70                    5
# 11              23             0.02             0.00                   10
# 16               9             0.27             0.00                    5
# 20              45             0.35             0.22                   50
# 21              56             0.31             0.28                   60
# 22              44             0.19             0.21                   10
#
#     Post_warranty_percent  GROUP
# 1                      95      0
# 3                      95      0
# 11                     90      0
# 16                     95      0
# 20                     50      0
# 21                     40      0
# 22                     90      0

# %%
tech_supp_df[tech_supp_df["GROUP"]==1]
# Out:
#                                PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 0           Temperature control not working          170                1.3
# 2                     Fan swing not working            5                1.0
# 7       App takes a long time to initialize          165                1.2
# 8   Unable to connect the App to the device          321                1.0
# 12            AC controller sofware missing          193                1.2
# 14                   Remote Keys get stuck           450                1.0
# 15       Unable to operate menu from remote          520                1.0
# 17                   Freshner holder stuck           140                1.7
# 19                WIFI connectivity breaks           290                1.1
#
#     Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 0               32             0.04             0.00                   75
# 2               35             0.02             0.20                   90
# 7               32             0.03             0.00                   95
# 8                5             0.21             0.00                   60
# 12              33             0.03             0.00                  100
# 14               8             0.25             0.00                  100
# 15               7             0.28             0.00                  100
# 17              23             0.05             0.04                   60
# 19              11             0.22             0.00                   90
#
#     Post_warranty_percent  GROUP
# 0                      25      1
# 2                      10      1
# 7                       5      1
# 8                      40      1
# 12                      0      1
# 14                      0      1
# 15                      0      1
# 17                     40      1
# 19                     10      1

# %%
tech_supp_df[tech_supp_df["GROUP"]==2]
# Out:
#                             PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 4             Forgot mobile app password           45                2.3
# 5                      AC stops abruptly           47                3.1
# 6       App hangs while entring commands           12                4.0
# 9   Reinstalling the app hangs the phone           22                3.3
# 10  Mobile screen blanks on use of phone           23                4.3
# 13              AC remote does not  work           24                2.8
# 18          Factory settings not working           72                2.3
#
#     Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 4               54             0.15             0.00                   99
# 5              132             0.30             0.03                  100
# 6              154             0.02             0.05                  100
# 9              140             0.14             0.01                   95
# 10             143             0.21             0.06                  100
# 13             180             0.04             0.00                  100
# 18             125             0.02             0.00                  100
#
#     Post_warranty_percent  GROUP
# 4                       1      2
# 5                       0      2
# 6                       0      2
# 9                       5      2
# 10                      0      2
# 13                      0      2
# 18                      0      2

# %% [markdown]
# ### Analyze the distribution of the data among the two groups (K = 3). One of the most informative visual tool is boxplot.

# %%
techSuppClust = tech_supp_df.groupby(['GROUP'])
techSuppClust.mean()
# Out:
#        no_of_cases  Avg_pending_calls  Avg_resol_time  recurrence_freq  \
# GROUP
# 0       112.142857           1.828571       47.857143         0.165714
# 1       250.444444           1.166667       20.666667         0.125556
# 2        35.000000           3.157143      132.571429         0.125714
#
#        Replace_percent  In_warranty_percent  Post_warranty_percent
# GROUP
# 0             0.272857            20.714286              79.285714
# 1             0.026667            85.555556              14.444444
# 2             0.021429            99.142857               0.857143

# %%
techSuppScaled
# Out:
#     no_of_cases  Avg_pending_calls  Avg_resol_time  recurrence_freq  \
# 0      0.179429          -0.701207       -0.538351        -0.843188
# 1     -0.862176           0.027143        1.510857        -1.101765
# 2     -0.908323          -1.013357       -0.486253        -1.015573
# 3     -0.921508           0.027143       -0.955140        -1.101765
# 4     -0.644625           0.339294       -0.156296         0.104930
# 5     -0.631441           1.171694        1.198266         1.397818
# 6     -0.862176           2.108144        1.580322        -1.015573
# 7      0.146467          -0.805257       -0.538351        -0.929380
# 8      1.174886          -1.013357       -1.007238         0.622085
# 9     -0.796251           1.379794        1.337195         0.018738
# 10    -0.789659           2.420294        1.389294         0.622085
# 11     0.574975          -0.701207       -0.694647        -1.015573
# 12     0.331055          -0.805257       -0.520985        -0.929380
# 13    -0.783067           0.859544        2.031842        -0.843188
# 14     2.025311          -1.013357       -0.955140         0.966855
# 15     2.486781          -1.013357       -0.972506         1.225433
# 16     1.629764          -1.013357       -0.937773         1.139240
# 17    -0.018344          -0.285007       -0.694647        -0.756995
# 18    -0.466630           0.339294        1.076703        -1.015573
# 19     0.970521          -0.909307       -0.903041         0.708278
# 20    -0.750104           0.235244       -0.312591         1.828780
# 21    -0.657810           0.131194       -0.121563         1.484010
# 22    -0.427075           0.235244       -0.329957         0.449700
#
#     Replace_percent  In_warranty_percent  Post_warranty_percent  GROUP
# 0         -0.561463             0.138067              -0.138067      1
# 1          2.245854            -1.778204               1.778204      0
# 2          0.561463             0.548696              -0.548696      1
# 3          3.368781            -1.778204               1.778204      0
# 4         -0.561463             0.795074              -0.795074      2
# 5         -0.393024             0.822449              -0.822449      2
# 6         -0.280732             0.822449              -0.822449      2
# 7         -0.561463             0.685572              -0.685572      1
# 8         -0.561463            -0.272563               0.272563      1
# 9         -0.505317             0.685572              -0.685572      2
# 10        -0.224585             0.822449              -0.822449      2
# 11        -0.561463            -1.641327               1.641327      0
# 12        -0.561463             0.822449              -0.822449      1
# 13        -0.561463             0.822449              -0.822449      2
# 14        -0.561463             0.822449              -0.822449      1
# 15        -0.561463             0.822449              -0.822449      1
# 16        -0.561463            -1.778204               1.778204      0
# 17        -0.336878            -0.272563               0.272563      1
# 18        -0.561463             0.822449              -0.822449      2
# 19        -0.561463             0.548696              -0.548696      1
# 20         0.673756            -0.546316               0.546316      0
# 21         1.010634            -0.272563               0.272563      0
# 22         0.617610            -1.641327               1.641327      0

# %%
techSuppScaled.boxplot(by='GROUP', layout = (2,4),figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'Avg_pending_calls'}, xlabel='[GROUP]'>,
#         <AxesSubplot:title={'center':'Avg_resol_time'}, xlabel='[GROUP]'>,
#         <AxesSubplot:title={'center':'In_warranty_percent'}, xlabel='[GROUP]'>,
#         <AxesSubplot:title={'center':'Post_warranty_percent'}, xlabel='[GROUP]'>],
#        [<AxesSubplot:title={'center':'Replace_percent'}, xlabel='[GROUP]'>,
#         <AxesSubplot:title={'center':'no_of_cases'}, xlabel='[GROUP]'>,
#         <AxesSubplot:title={'center':'recurrence_freq'}, xlabel='[GROUP]'>,
#         <AxesSubplot:>]], dtype=object)

# %%
#  Let us next try with K = 5, the next elbow point

# %%
# Let us first start with K = 5
final_model=KMeans(5)
final_model.fit(techSuppScaled)
prediction=final_model.predict(techSuppScaled)

#Append the prediction 
tech_supp_df["GROUP"] = prediction
techSuppScaled["GROUP"] = prediction
print("Groups Assigned : \n")
tech_supp_df.head()
# Out:
# Groups Assigned :
#                        PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 0   Temperature control not working          170                1.3
# 1  power chord does not tightly fit           12                2.0
# 2             Fan swing not working            5                1.0
# 3           Main switch does not on            3                2.0
# 4        Forgot mobile app password           45                2.3
#
#    Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 0              32             0.04              0.0                   75
# 1             150             0.01              0.5                    5
# 2              35             0.02              0.2                   90
# 3               8             0.01              0.7                    5
# 4              54             0.15              0.0                   99
#
#    Post_warranty_percent  GROUP
# 0                     25      1
# 1                     95      4
# 2                     10      1
# 3                     95      4
# 4                      1      0

# %%
tech_supp_df[tech_supp_df["GROUP"]==0]
# Out:
#                             PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 4             Forgot mobile app password           45                2.3
# 5                      AC stops abruptly           47                3.1
# 6       App hangs while entring commands           12                4.0
# 9   Reinstalling the app hangs the phone           22                3.3
# 10  Mobile screen blanks on use of phone           23                4.3
# 13              AC remote does not  work           24                2.8
# 18          Factory settings not working           72                2.3
#
#     Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 4               54             0.15             0.00                   99
# 5              132             0.30             0.03                  100
# 6              154             0.02             0.05                  100
# 9              140             0.14             0.01                   95
# 10             143             0.21             0.06                  100
# 13             180             0.04             0.00                  100
# 18             125             0.02             0.00                  100
#
#     Post_warranty_percent  GROUP
# 4                       1      0
# 5                       0      0
# 6                       0      0
# 9                       5      0
# 10                      0      0
# 13                      0      0
# 18                      0      0

# %%
tech_supp_df[tech_supp_df["GROUP"]==1]
# Out:
#                            PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 0       Temperature control not working          170                1.3
# 2                 Fan swing not working            5                1.0
# 7   App takes a long time to initialize          165                1.2
# 12        AC controller sofware missing          193                1.2
# 17               Freshner holder stuck           140                1.7
#
#     Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 0               32             0.04             0.00                   75
# 2               35             0.02             0.20                   90
# 7               32             0.03             0.00                   95
# 12              33             0.03             0.00                  100
# 17              23             0.05             0.04                   60
#
#     Post_warranty_percent  GROUP
# 0                      25      1
# 2                      10      1
# 7                       5      1
# 12                      0      1
# 17                     40      1

# %%
tech_supp_df[tech_supp_df["GROUP"]==2]
# Out:
#                                PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 8   Unable to connect the App to the device          321                1.0
# 14                   Remote Keys get stuck           450                1.0
# 15       Unable to operate menu from remote          520                1.0
# 19                WIFI connectivity breaks           290                1.1
#
#     Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 8                5             0.21              0.0                   60
# 14               8             0.25              0.0                  100
# 15               7             0.28              0.0                  100
# 19              11             0.22              0.0                   90
#
#     Post_warranty_percent  GROUP
# 8                      40      2
# 14                      0      2
# 15                      0      2
# 19                     10      2

# %%
tech_supp_df[tech_supp_df["GROUP"]==3]
# Out:
#                                  PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 11              Cluttered with popup messages          230                1.3
# 16               Motor noise from the system           390                1.0
# 20  Battery backup does not get fully charged           29                2.2
# 21           Battery does not last full 8 hrs           43                2.1
# 22             Fan speed varies at on its own           78                2.2
#
#     Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 11              23             0.02             0.00                   10
# 16               9             0.27             0.00                    5
# 20              45             0.35             0.22                   50
# 21              56             0.31             0.28                   60
# 22              44             0.19             0.21                   10
#
#     Post_warranty_percent  GROUP
# 11                     90      3
# 16                     95      3
# 20                     50      3
# 21                     40      3
# 22                     90      3

# %%
tech_supp_df[tech_supp_df["GROUP"]==4]
# Out:
#                        PROBLEM_TYPE  no_of_cases  Avg_pending_calls  \
# 1  power chord does not tightly fit           12                2.0
# 3           Main switch does not on            3                2.0
#
#    Avg_resol_time  recurrence_freq  Replace_percent  In_warranty_percent  \
# 1             150             0.01              0.5                    5
# 3               8             0.01              0.7                    5
#
#    Post_warranty_percent  GROUP
# 1                     95      4
# 3                     95      4

# %%
techSuppClust = tech_supp_df.groupby(['GROUP'])
techSuppClust.mean()
# Out:
#        no_of_cases  Avg_pending_calls  Avg_resol_time  recurrence_freq  \
# GROUP
# 0            35.00           3.157143      132.571429         0.125714
# 1           134.60           1.280000       31.000000         0.034000
# 2           395.25           1.025000        7.750000         0.240000
# 3           154.00           1.760000       35.400000         0.228000
# 4             7.50           2.000000       79.000000         0.010000
#
#        Replace_percent  In_warranty_percent  Post_warranty_percent
# GROUP
# 0             0.021429            99.142857               0.857143
# 1             0.048000            84.000000              16.000000
# 2             0.000000            87.500000              12.500000
# 3             0.142000            27.000000              73.000000
# 4             0.600000             5.000000              95.000000

# %%
techSuppScaled.boxplot(by='GROUP', layout = (2,4),figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'Avg_pending_calls'}, xlabel='[GROUP]'>,
#         <AxesSubplot:title={'center':'Avg_resol_time'}, xlabel='[GROUP]'>,
#         <AxesSubplot:title={'center':'In_warranty_percent'}, xlabel='[GROUP]'>,
#         <AxesSubplot:title={'center':'Post_warranty_percent'}, xlabel='[GROUP]'>],
#        [<AxesSubplot:title={'center':'Replace_percent'}, xlabel='[GROUP]'>,
#         <AxesSubplot:title={'center':'no_of_cases'}, xlabel='[GROUP]'>,
#         <AxesSubplot:title={'center':'recurrence_freq'}, xlabel='[GROUP]'>,
#         <AxesSubplot:>]], dtype=object)
